# %%
# Compute activations for both specified layers 
# Based on the code provided in https://github.com/cjspoerer/rcnn-sat

import urllib
import numpy as np
import tensorflow as tf
from rcnn_sat import preprocess_image, bl_net
input_layer = tf.keras.layers.Input((128, 128, 3))
model = bl_net(input_layer, classes=1000, cumulative_readout=True)

model.load_weights('bl_imagenet.h5') # load imagenet or ecoset weights

import cv2
import os

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images


stim = load_images_from_folder('... path to images')

# compute activations at different layers 
activations = [[] for _ in range(60)]
layers = ['ReLU_Layer_0_Time_0', 'ReLU_Layer_0_Time_1', 'ReLU_Layer_0_Time_2', 'ReLU_Layer_0_Time_3',
         'ReLU_Layer_0_Time_4','ReLU_Layer_0_Time_5','ReLU_Layer_0_Time_6','ReLU_Layer_0_Time_7', 
          'ReLU_Layer_1_Time_0', 'ReLU_Layer_1_Time_1', 'ReLU_Layer_1_Time_2', 'ReLU_Layer_1_Time_3',
         'ReLU_Layer_1_Time_4','ReLU_Layer_1_Time_5','ReLU_Layer_1_Time_6','ReLU_Layer_1_Time_7', 
          'ReLU_Layer_2_Time_0', 'ReLU_Layer_2_Time_1', 'ReLU_Layer_2_Time_2', 'ReLU_Layer_2_Time_3',
         'ReLU_Layer_2_Time_4','ReLU_Layer_2_Time_5','ReLU_Layer_2_Time_6','ReLU_Layer_2_Time_7', 
          'ReLU_Layer_3_Time_0', 'ReLU_Layer_3_Time_1', 'ReLU_Layer_3_Time_2', 'ReLU_Layer_3_Time_3',
         'ReLU_Layer_3_Time_4','ReLU_Layer_3_Time_5','ReLU_Layer_3_Time_6','ReLU_Layer_3_Time_7', 
          'ReLU_Layer_4_Time_0', 'ReLU_Layer_4_Time_1', 'ReLU_Layer_4_Time_2', 'ReLU_Layer_4_Time_3',
         'ReLU_Layer_4_Time_4','ReLU_Layer_4_Time_5','ReLU_Layer_4_Time_6','ReLU_Layer_4_Time_7', 
          'ReLU_Layer_5_Time_0', 'ReLU_Layer_5_Time_1', 'ReLU_Layer_5_Time_2', 'ReLU_Layer_5_Time_3',
         'ReLU_Layer_5_Time_4','ReLU_Layer_5_Time_5','ReLU_Layer_5_Time_6','ReLU_Layer_5_Time_7', 
          'ReLU_Layer_6_Time_0', 'ReLU_Layer_6_Time_1', 'ReLU_Layer_6_Time_2', 'ReLU_Layer_6_Time_3',
         'ReLU_Layer_6_Time_4','ReLU_Layer_6_Time_5','ReLU_Layer_6_Time_6','ReLU_Layer_6_Time_7', 
         ]

for layi in range(0, 56):
    print(layers[layi])
    for i in range(0, 60):
        x = cv2.resize(stim[i], (128, 128))
        x1 = np.expand_dims(x, axis=0)
        y = preprocess_image(x1)
        get_layer_activation = tf.keras.backend.function([model.input],[model.get_layer(layers[layi]).output])
        y = get_layer_activation(y)
        y = y[0].flatten()
        activations[layi].append(y)
        
# compute RDMs
from scipy.stats import spearmanr
import matplotlib.pyplot as plt
RDMs = [];
for i in range (0,56):
    y = activations[i]
    rsm, pval = spearmanr(np.transpose(y))
    RDMs.append(rsm)
    
#export to matlab format 
from scipy.io import savemat
mdic = {"a": RDMs, "label": "experiment"}
savemat("matlab_matrix.mat", mdic)

# %%
print(model.summary())
# Out:
# Model: "bl_net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# RCL_0_BConv (Conv2D)            (None, 128, 128, 96) 14112       input_1[0][0]
# __________________________________________________________________________________________________
# RCL_0_ConvSum (Lambda)          (None, 128, 128, 96) 0           RCL_0_BConv[0][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[0][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[1][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[2][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[3][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[4][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[5][0]
#                                                                  RCL_0_BConv[0][0]
#                                                                  RCL_0_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_0 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_0 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_0 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_0[0][0]
# __________________________________________________________________________________________________
# RCL_0_LConv (Conv2D)            (None, 128, 128, 96) 451584      ReLU_Layer_0_Time_0[0][0]
#                                                                  ReLU_Layer_0_Time_1[0][0]
#                                                                  ReLU_Layer_0_Time_2[0][0]
#                                                                  ReLU_Layer_0_Time_3[0][0]
#                                                                  ReLU_Layer_0_Time_4[0][0]
#                                                                  ReLU_Layer_0_Time_5[0][0]
#                                                                  ReLU_Layer_0_Time_6[0][0]
# __________________________________________________________________________________________________
# RCL_1_BConv (Conv2D)            (None, 64, 64, 128)  307200      MaxPool_Layer_1_Time_0[0][0]
#                                                                  MaxPool_Layer_1_Time_1[0][0]
#                                                                  MaxPool_Layer_1_Time_2[0][0]
#                                                                  MaxPool_Layer_1_Time_3[0][0]
#                                                                  MaxPool_Layer_1_Time_4[0][0]
#                                                                  MaxPool_Layer_1_Time_5[0][0]
#                                                                  MaxPool_Layer_1_Time_6[0][0]
#                                                                  MaxPool_Layer_1_Time_7[0][0]
# __________________________________________________________________________________________________
# RCL_1_ConvSum (Lambda)          (None, 64, 64, 128)  0           RCL_1_BConv[0][0]
#                                                                  RCL_1_BConv[1][0]
#                                                                  RCL_1_LConv[0][0]
#                                                                  RCL_1_BConv[2][0]
#                                                                  RCL_1_LConv[1][0]
#                                                                  RCL_1_BConv[3][0]
#                                                                  RCL_1_LConv[2][0]
#                                                                  RCL_1_BConv[4][0]
#                                                                  RCL_1_LConv[3][0]
#                                                                  RCL_1_BConv[5][0]
#                                                                  RCL_1_LConv[4][0]
#                                                                  RCL_1_BConv[6][0]
#                                                                  RCL_1_LConv[5][0]
#                                                                  RCL_1_BConv[7][0]
#                                                                  RCL_1_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_1 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[1][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_0 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_1 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_1[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_0 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_1 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_0 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_0[0][0]
# __________________________________________________________________________________________________
# RCL_1_LConv (Conv2D)            (None, 64, 64, 128)  409600      ReLU_Layer_1_Time_0[0][0]
#                                                                  ReLU_Layer_1_Time_1[0][0]
#                                                                  ReLU_Layer_1_Time_2[0][0]
#                                                                  ReLU_Layer_1_Time_3[0][0]
#                                                                  ReLU_Layer_1_Time_4[0][0]
#                                                                  ReLU_Layer_1_Time_5[0][0]
#                                                                  ReLU_Layer_1_Time_6[0][0]
# __________________________________________________________________________________________________
# RCL_2_BConv (Conv2D)            (None, 32, 32, 192)  221184      MaxPool_Layer_2_Time_0[0][0]
#                                                                  MaxPool_Layer_2_Time_1[0][0]
#                                                                  MaxPool_Layer_2_Time_2[0][0]
#                                                                  MaxPool_Layer_2_Time_3[0][0]
#                                                                  MaxPool_Layer_2_Time_4[0][0]
#                                                                  MaxPool_Layer_2_Time_5[0][0]
#                                                                  MaxPool_Layer_2_Time_6[0][0]
#                                                                  MaxPool_Layer_2_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_2 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[2][0]
# __________________________________________________________________________________________________
# RCL_2_ConvSum (Lambda)          (None, 32, 32, 192)  0           RCL_2_BConv[0][0]
#                                                                  RCL_2_BConv[1][0]
#                                                                  RCL_2_LConv[0][0]
#                                                                  RCL_2_BConv[2][0]
#                                                                  RCL_2_LConv[1][0]
#                                                                  RCL_2_BConv[3][0]
#                                                                  RCL_2_LConv[2][0]
#                                                                  RCL_2_BConv[4][0]
#                                                                  RCL_2_LConv[3][0]
#                                                                  RCL_2_BConv[5][0]
#                                                                  RCL_2_LConv[4][0]
#                                                                  RCL_2_BConv[6][0]
#                                                                  RCL_2_LConv[5][0]
#                                                                  RCL_2_BConv[7][0]
#                                                                  RCL_2_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_1 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[1][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_2 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_2[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_0 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_1 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_2 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_2[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_0 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_1 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_0 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_0[0][0]
# __________________________________________________________________________________________________
# RCL_2_LConv (Conv2D)            (None, 32, 32, 192)  331776      ReLU_Layer_2_Time_0[0][0]
#                                                                  ReLU_Layer_2_Time_1[0][0]
#                                                                  ReLU_Layer_2_Time_2[0][0]
#                                                                  ReLU_Layer_2_Time_3[0][0]
#                                                                  ReLU_Layer_2_Time_4[0][0]
#                                                                  ReLU_Layer_2_Time_5[0][0]
#                                                                  ReLU_Layer_2_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_3 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[3][0]
# __________________________________________________________________________________________________
# RCL_3_BConv (Conv2D)            (None, 16, 16, 256)  442368      MaxPool_Layer_3_Time_0[0][0]
#                                                                  MaxPool_Layer_3_Time_1[0][0]
#                                                                  MaxPool_Layer_3_Time_2[0][0]
#                                                                  MaxPool_Layer_3_Time_3[0][0]
#                                                                  MaxPool_Layer_3_Time_4[0][0]
#                                                                  MaxPool_Layer_3_Time_5[0][0]
#                                                                  MaxPool_Layer_3_Time_6[0][0]
#                                                                  MaxPool_Layer_3_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_2 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[2][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_3 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_3[0][0]
# __________________________________________________________________________________________________
# RCL_3_ConvSum (Lambda)          (None, 16, 16, 256)  0           RCL_3_BConv[0][0]
#                                                                  RCL_3_BConv[1][0]
#                                                                  RCL_3_LConv[0][0]
#                                                                  RCL_3_BConv[2][0]
#                                                                  RCL_3_LConv[1][0]
#                                                                  RCL_3_BConv[3][0]
#                                                                  RCL_3_LConv[2][0]
#                                                                  RCL_3_BConv[4][0]
#                                                                  RCL_3_LConv[3][0]
#                                                                  RCL_3_BConv[5][0]
#                                                                  RCL_3_LConv[4][0]
#                                                                  RCL_3_BConv[6][0]
#                                                                  RCL_3_LConv[5][0]
#                                                                  RCL_3_BConv[7][0]
#                                                                  RCL_3_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_1 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[1][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_2 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_3 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_3[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_0 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_1 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_2 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_2[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_0 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_1 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_1[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_4 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[4][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_0 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_0[0][0]
# __________________________________________________________________________________________________
# RCL_3_LConv (Conv2D)            (None, 16, 16, 256)  589824      ReLU_Layer_3_Time_0[0][0]
#                                                                  ReLU_Layer_3_Time_1[0][0]
#                                                                  ReLU_Layer_3_Time_2[0][0]
#                                                                  ReLU_Layer_3_Time_3[0][0]
#                                                                  ReLU_Layer_3_Time_4[0][0]
#                                                                  ReLU_Layer_3_Time_5[0][0]
#                                                                  ReLU_Layer_3_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_3 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[3][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_4 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_4[0][0]
# __________________________________________________________________________________________________
# RCL_4_BConv (Conv2D)            (None, 8, 8, 512)    1179648     MaxPool_Layer_4_Time_0[0][0]
#                                                                  MaxPool_Layer_4_Time_1[0][0]
#                                                                  MaxPool_Layer_4_Time_2[0][0]
#                                                                  MaxPool_Layer_4_Time_3[0][0]
#                                                                  MaxPool_Layer_4_Time_4[0][0]
#                                                                  MaxPool_Layer_4_Time_5[0][0]
#                                                                  MaxPool_Layer_4_Time_6[0][0]
#                                                                  MaxPool_Layer_4_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_2 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[2][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_3 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_4 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_4[0][0]
# __________________________________________________________________________________________________
# RCL_4_ConvSum (Lambda)          (None, 8, 8, 512)    0           RCL_4_BConv[0][0]
#                                                                  RCL_4_BConv[1][0]
#                                                                  RCL_4_LConv[0][0]
#                                                                  RCL_4_BConv[2][0]
#                                                                  RCL_4_LConv[1][0]
#                                                                  RCL_4_BConv[3][0]
#                                                                  RCL_4_LConv[2][0]
#                                                                  RCL_4_BConv[4][0]
#                                                                  RCL_4_LConv[3][0]
#                                                                  RCL_4_BConv[5][0]
#                                                                  RCL_4_LConv[4][0]
#                                                                  RCL_4_BConv[6][0]
#                                                                  RCL_4_LConv[5][0]
#                                                                  RCL_4_BConv[7][0]
#                                                                  RCL_4_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_1 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[1][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_2 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_3 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_3[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_0 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_1 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_2 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_2[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_5 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_0 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_1 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_1[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_4 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[4][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_5 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_0 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_0[0][0]
# __________________________________________________________________________________________________
# RCL_4_LConv (Conv2D)            (None, 8, 8, 512)    2359296     ReLU_Layer_4_Time_0[0][0]
#                                                                  ReLU_Layer_4_Time_1[0][0]
#                                                                  ReLU_Layer_4_Time_2[0][0]
#                                                                  ReLU_Layer_4_Time_3[0][0]
#                                                                  ReLU_Layer_4_Time_4[0][0]
#                                                                  ReLU_Layer_4_Time_5[0][0]
#                                                                  ReLU_Layer_4_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_3 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[3][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_4 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_4[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_5 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_5[0][0]
# __________________________________________________________________________________________________
# RCL_5_BConv (Conv2D)            (None, 4, 4, 1024)   4718592     MaxPool_Layer_5_Time_0[0][0]
#                                                                  MaxPool_Layer_5_Time_1[0][0]
#                                                                  MaxPool_Layer_5_Time_2[0][0]
#                                                                  MaxPool_Layer_5_Time_3[0][0]
#                                                                  MaxPool_Layer_5_Time_4[0][0]
#                                                                  MaxPool_Layer_5_Time_5[0][0]
#                                                                  MaxPool_Layer_5_Time_6[0][0]
#                                                                  MaxPool_Layer_5_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_2 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[2][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_3 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_4 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_4[0][0]
# __________________________________________________________________________________________________
# RCL_5_ConvSum (Lambda)          (None, 4, 4, 1024)   0           RCL_5_BConv[0][0]
#                                                                  RCL_5_BConv[1][0]
#                                                                  RCL_5_LConv[0][0]
#                                                                  RCL_5_BConv[2][0]
#                                                                  RCL_5_LConv[1][0]
#                                                                  RCL_5_BConv[3][0]
#                                                                  RCL_5_LConv[2][0]
#                                                                  RCL_5_BConv[4][0]
#                                                                  RCL_5_LConv[3][0]
#                                                                  RCL_5_BConv[5][0]
#                                                                  RCL_5_LConv[4][0]
#                                                                  RCL_5_BConv[6][0]
#                                                                  RCL_5_LConv[5][0]
#                                                                  RCL_5_BConv[7][0]
#                                                                  RCL_5_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_1 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[1][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_2 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_3 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_3[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_6 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_0 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_1 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_2 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_2[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_5 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_6 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_6[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_0 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_1 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_1[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_4 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[4][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_5 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_6 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_0 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_0[0][0]
# __________________________________________________________________________________________________
# RCL_5_LConv (Conv2D)            (None, 4, 4, 1024)   9437184     ReLU_Layer_5_Time_0[0][0]
#                                                                  ReLU_Layer_5_Time_1[0][0]
#                                                                  ReLU_Layer_5_Time_2[0][0]
#                                                                  ReLU_Layer_5_Time_3[0][0]
#                                                                  ReLU_Layer_5_Time_4[0][0]
#                                                                  ReLU_Layer_5_Time_5[0][0]
#                                                                  ReLU_Layer_5_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_3 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[3][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_4 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_4[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_5 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_5[0][0]
# __________________________________________________________________________________________________
# RCL_6_BConv (Conv2D)            (None, 2, 2, 2048)   2097152     MaxPool_Layer_6_Time_0[0][0]
#                                                                  MaxPool_Layer_6_Time_1[0][0]
#                                                                  MaxPool_Layer_6_Time_2[0][0]
#                                                                  MaxPool_Layer_6_Time_3[0][0]
#                                                                  MaxPool_Layer_6_Time_4[0][0]
#                                                                  MaxPool_Layer_6_Time_5[0][0]
#                                                                  MaxPool_Layer_6_Time_6[0][0]
#                                                                  MaxPool_Layer_6_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_2 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[2][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_3 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_4 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_4[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_0_Time_7 (Batch (None, 128, 128, 96) 384         RCL_0_ConvSum[7][0]
# __________________________________________________________________________________________________
# RCL_6_ConvSum (Lambda)          (None, 2, 2, 2048)   0           RCL_6_BConv[0][0]
#                                                                  RCL_6_BConv[1][0]
#                                                                  RCL_6_LConv[0][0]
#                                                                  RCL_6_BConv[2][0]
#                                                                  RCL_6_LConv[1][0]
#                                                                  RCL_6_BConv[3][0]
#                                                                  RCL_6_LConv[2][0]
#                                                                  RCL_6_BConv[4][0]
#                                                                  RCL_6_LConv[3][0]
#                                                                  RCL_6_BConv[5][0]
#                                                                  RCL_6_LConv[4][0]
#                                                                  RCL_6_BConv[6][0]
#                                                                  RCL_6_LConv[5][0]
#                                                                  RCL_6_BConv[7][0]
#                                                                  RCL_6_LConv[6][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_1 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[1][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_2 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_3 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_3[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_6 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[6][0]
# __________________________________________________________________________________________________
# ReLU_Layer_0_Time_7 (Activation (None, 128, 128, 96) 0           BatchNorm_Layer_0_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_0 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_1 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_2 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_2[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_5 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_6 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_1_Time_7 (MaxPool (None, 64, 64, 96)   0           ReLU_Layer_0_Time_7[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_0 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_0[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_1 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_1[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_4 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[4][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_5 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_6 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_6[0][0]
# __________________________________________________________________________________________________
# RCL_6_LConv (Conv2D)            (None, 2, 2, 2048)   4194304     ReLU_Layer_6_Time_0[0][0]
#                                                                  ReLU_Layer_6_Time_1[0][0]
#                                                                  ReLU_Layer_6_Time_2[0][0]
#                                                                  ReLU_Layer_6_Time_3[0][0]
#                                                                  ReLU_Layer_6_Time_4[0][0]
#                                                                  ReLU_Layer_6_Time_5[0][0]
#                                                                  ReLU_Layer_6_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_3 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[3][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_4 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_4[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_5 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_5[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_2 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[2][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_3 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_4 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_4[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_1_Time_7 (Batch (None, 64, 64, 128)  512         RCL_1_ConvSum[7][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_1 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[1][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_2 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_3 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_3[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_6 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[6][0]
# __________________________________________________________________________________________________
# ReLU_Layer_1_Time_7 (Activation (None, 64, 64, 128)  0           BatchNorm_Layer_1_Time_7[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_1 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_1[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_2 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_2[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_5 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_6 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_2_Time_7 (MaxPool (None, 32, 32, 128)  0           ReLU_Layer_1_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_4 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[4][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_5 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_6 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_3 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[3][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_4 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_4[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_5 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_5[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_2 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[2][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_3 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_4 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_4[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_2_Time_7 (Batch (None, 32, 32, 192)  768         RCL_2_ConvSum[7][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_2 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_2[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_3 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_3[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_6 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[6][0]
# __________________________________________________________________________________________________
# ReLU_Layer_2_Time_7 (Activation (None, 32, 32, 192)  0           BatchNorm_Layer_2_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_5 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_6 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_3_Time_7 (MaxPool (None, 16, 16, 192)  0           ReLU_Layer_2_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_4 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[4][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_5 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_6 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_3 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[3][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_4 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_4[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_5 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_5[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_3 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_3[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_4 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_4[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_3_Time_7 (Batch (None, 16, 16, 256)  1024        RCL_3_ConvSum[7][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_6 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[6][0]
# __________________________________________________________________________________________________
# ReLU_Layer_3_Time_7 (Activation (None, 16, 16, 256)  0           BatchNorm_Layer_3_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_5 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_6 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_4_Time_7 (MaxPool (None, 8, 8, 256)    0           ReLU_Layer_3_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_4 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[4][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_5 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_6 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_6[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_4 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_4[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_5 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_5[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_4_Time_7 (Batch (None, 8, 8, 512)    2048        RCL_4_ConvSum[7][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_6 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[6][0]
# __________________________________________________________________________________________________
# ReLU_Layer_4_Time_7 (Activation (None, 8, 8, 512)    0           BatchNorm_Layer_4_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_5 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[5][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_6 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_5_Time_7 (MaxPool (None, 4, 4, 512)    0           ReLU_Layer_4_Time_7[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_5 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_5[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_6 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_6[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_5_Time_7 (Batch (None, 4, 4, 1024)   4096        RCL_5_ConvSum[7][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_6 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[6][0]
# __________________________________________________________________________________________________
# ReLU_Layer_5_Time_7 (Activation (None, 4, 4, 1024)   0           BatchNorm_Layer_5_Time_7[0][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_6 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_6[0][0]
# __________________________________________________________________________________________________
# MaxPool_Layer_6_Time_7 (MaxPool (None, 2, 2, 1024)   0           ReLU_Layer_5_Time_7[0][0]
# __________________________________________________________________________________________________
# BatchNorm_Layer_6_Time_7 (Batch (None, 2, 2, 2048)   8192        RCL_6_ConvSum[7][0]
# __________________________________________________________________________________________________
# ReLU_Layer_6_Time_7 (Activation (None, 2, 2, 2048)   0           BatchNorm_Layer_6_Time_7[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_0 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_0[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_1 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_1[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_2 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_2[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_3 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_3[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_4 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_4[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_5 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_5[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_6 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_6[0][0]
# __________________________________________________________________________________________________
# GlobalAvgPool_Time_7 (GlobalAve (None, 2048)         0           ReLU_Layer_6_Time_7[0][0]
# __________________________________________________________________________________________________
# ReadoutDense (Dense)            (None, 1000)         2049000     GlobalAvgPool_Time_0[0][0]
#                                                                  GlobalAvgPool_Time_1[0][0]
#                                                                  GlobalAvgPool_Time_2[0][0]
#                                                                  GlobalAvgPool_Time_3[0][0]
#                                                                  GlobalAvgPool_Time_4[0][0]
#                                                                  GlobalAvgPool_Time_5[0][0]
#                                                                  GlobalAvgPool_Time_6[0][0]
#                                                                  GlobalAvgPool_Time_7[0][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_1 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_2 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
#                                                                  ReadoutDense[2][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_3 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
#                                                                  ReadoutDense[2][0]
#                                                                  ReadoutDense[3][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_4 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
#                                                                  ReadoutDense[2][0]
#                                                                  ReadoutDense[3][0]
#                                                                  ReadoutDense[4][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_5 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
#                                                                  ReadoutDense[2][0]
#                                                                  ReadoutDense[3][0]
#                                                                  ReadoutDense[4][0]
#                                                                  ReadoutDense[5][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_6 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
#                                                                  ReadoutDense[2][0]
#                                                                  ReadoutDense[3][0]
#                                                                  ReadoutDense[4][0]
#                                                                  ReadoutDense[5][0]
#                                                                  ReadoutDense[6][0]
# __________________________________________________________________________________________________
# CumulativeReadout_Time_7 (Add)  (None, 1000)         0           ReadoutDense[0][0]
#                                                                  ReadoutDense[1][0]
#                                                                  ReadoutDense[2][0]
#                                                                  ReadoutDense[3][0]
#                                                                  ReadoutDense[4][0]
#                                                                  ReadoutDense[5][0]
#                                                                  ReadoutDense[6][0]
#                                                                  ReadoutDense[7][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_0 (Activation)     (None, 1000)         0           ReadoutDense[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_1 (Activation)     (None, 1000)         0           CumulativeReadout_Time_1[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_2 (Activation)     (None, 1000)         0           CumulativeReadout_Time_2[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_3 (Activation)     (None, 1000)         0           CumulativeReadout_Time_3[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_4 (Activation)     (None, 1000)         0           CumulativeReadout_Time_4[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_5 (Activation)     (None, 1000)         0           CumulativeReadout_Time_5[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_6 (Activation)     (None, 1000)         0           CumulativeReadout_Time_6[0][0]
# __________________________________________________________________________________________________
# Sotfmax_Time_7 (Activation)     (None, 1000)         0           CumulativeReadout_Time_7[0][0]
# ==================================================================================================
# Total params: 28,939,016
# Trainable params: 28,870,920
# Non-trainable params: 68,096
# __________________________________________________________________________________________________
# None
